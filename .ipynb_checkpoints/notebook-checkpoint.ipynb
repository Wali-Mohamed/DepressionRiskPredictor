# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, accuracy_score, roc_auc_score
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load

# %%
train=pd.read_csv('train.csv')
original=pd.read_csv('final_depression_dataset_1.csv')
test=pd.read_csv('test.csv')

# %%
#test.head()

# %%
original.head(2)
# original is missing id column and test is missing depression column
train.shape,original.shape, test.shape
# Out:
# ((140700, 20), (2556, 19), (93800, 19))

# %%
train.head(5)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# 1                 NaN               3.0  Less than 5 hours      Unhealthy
# 2                 2.0               NaN          5-6 hours        Healthy
# 3                 NaN               1.0  Less than 5 hours       Moderate
# 4                 NaN               1.0          5-6 hours      Unhealthy
#
#     Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0      BHM                                    No               1.0
# 1      LLB                                   Yes               7.0
# 2  B.Pharm                                   Yes               3.0
# 3      BBA                                   Yes              10.0
# 4      BBA                                   Yes               9.0
#
#    Financial Stress Family History of Mental Illness  Depression
# 0               2.0                               No           0
# 1               3.0                               No           1
# 2               1.0                               No           1
# 3               1.0                              Yes           1
# 4               4.0                              Yes           0

# %%
original['Depression'] = original['Depression'].map({"Yes": 1, "No": 0})
df = pd.concat([train, original], ignore_index=True)

# %% [markdown]
# ## Clean and Explore

# %%
df=train.copy()
len(df.columns)
# Out:
# 20

# %%
#df.drop(columns=['id', 'Name'], inplace=True)

# %%
#df.isnull().sum()

# %%
#df.isnull().sum()/df.shape[0]*100

# %%
df.columns=df.columns.str.lower().str.replace(' ', '-').to_list()

# %%
# get categorical columns
cat_cols=df.columns[df.dtypes=='O'].to_list()
# get numerical columns
num_cols = [cols for cols in df.select_dtypes('number').columns if cols!= 'id' and cols!='depression']

# %%
len(cat_cols) , len(num_cols)
# Out:
# (10, 8)

# %%
cat_cols
# Out:
# ['name',
#  'gender',
#  'city',
#  'working-professional-or-student',
#  'profession',
#  'sleep-duration',
#  'dietary-habits',
#  'degree',
#  'have-you-ever-had-suicidal-thoughts-?',
#  'family-history-of-mental-illness']

# %%
# Convert the content of all colums to lower case
for col in cat_cols:
    df[col]=df[col].str.lower()

# %%
#df.isnull().sum()

# %% [markdown]
# ## Handling missing value in categorical columns
# Classifying all the values having a value count of less than 100 to a different new class noise and fill the NaN values to new class missing.

# %%
threshold=100
for col in df.select_dtypes('object').columns:
    # fill in all NaN by 'missing'
    df[col] = df[col].fillna('missing')
    # computes the frequency of each unique value in the column, including NaN values
    # sets the value of the column to "noise" for all rows where the boolean condition (value count is less than threshold) is true.
    df.loc[df[col].value_counts(dropna=False)[df[col]].values < threshold, col] = "noise"

# %%
for col in num_cols:
        df[col]=df[col].fillna(0)

# %%
#df.isnull().sum()

# %%
#df.isnull().sum()/df.shape[0]*100

# %%
def preprocess(df):
     # Change columns titles to lower case
    df.columns=df.columns.str.lower().str.replace(' ', '-').to_list()
    # get numerical columns
    num_cols = [cols for cols in df.select_dtypes('number').columns if cols!= 'id' and cols!='depression']
   
    # get categorical columns
    cat_cols=df.columns[df.dtypes=='O'].to_list()
    # Change categorical column content to lower case
    for col in cat_cols:
        df[col]=df[col].str.lower()
    threshold=100
    for col in cat_cols:
        # fill in all NaN by 'missing'
        df[col] = df[col].fillna('missing')
        # computes the frequency of each unique value in the column, including NaN values
        # sets the value of the column to "noise" for all rows where the boolean condition (value count is less than threshold) is true.
        df.loc[df[col].value_counts(dropna=False)[df[col]].values < threshold, col] = "noise"
    for col in num_cols:
        df[col]=df[col].fillna(0)
    # remove name column as it does not affect the target
    cat_cols.remove('name')
    features=num_cols+cat_cols
    
    
    

    return features, df

# %%
features, df=preprocess(df)
len(features) , df.shape
# Out:
# (17, (140700, 20))

# %% [markdown]
# ## Base Model

# %%
df.depression.value_counts(normalize=True)  # base accuracy is 82%
# Out:
# depression
# 0    0.818287
# 1    0.181713
# Name: proportion, dtype: float64

# %% [markdown]
# ## Split

# %%
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (140700, 20)

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train_full.shape, df_test.shape
# Out:
# ((112560, 20), (28140, 20))

# %%
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=1)
df_train.shape, df_val.shape
# Out:
# ((84420, 20), (28140, 20))

# %%
# reset index 
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.depression.values
y_val = df_val.depression.values
y_test=df_test.depression.values

# %%
# drop target
del df_train['depression']
del df_val['depression']
del df_test['depression']

# %% [markdown]
# ## Exploratory data analysis

# %%
sns.histplot(data=df, x='age', bins=10, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.catplot(data=df, x='sleep-duration', hue='dietary-habits', kind='count', height=5, aspect=2)
plt.title("Sleep Duration vs. Dietary Habits")
plt.show()

# %%
sns.countplot(data=df, x='gender')
plt.title("Count of Gender")
plt.show()

# %%
sns.countplot(data=df, x='working-professional-or-student')
plt.title("Count of Professionals vs. Students")
plt.show()

# %%
df_train_full.depression.value_counts(normalize=True)
# Out:
# depression
# 0    0.817884
# 1    0.182116
# Name: proportion, dtype: float64

# %%
global_mean = df_train_full.depression.mean()
round(global_mean, 3)
# Out:
# np.float64(0.182)

# %%
df_train_full[cat_cols].nunique()
# Out:
# name                                     209
# gender                                     2
# city                                      31
# working-professional-or-student            2
# profession                                37
# sleep-duration                             5
# dietary-habits                             4
# degree                                    28
# have-you-ever-had-suicidal-thoughts-?      2
# family-history-of-mental-illness           2
# dtype: int64

# %%
female_mean = df_train_full[df_train_full.gender == 'female'].depression.mean()
print('gender == female:', round(female_mean, 3))

male_mean = df_train_full[df_train_full.gender == 'male'].depression.mean()
print('gender == male:  ', round(male_mean, 3))
# Out:
# gender == female: 0.179
# gender == male:   0.184

# %%
female_mean / global_mean
# Out:
# np.float64(0.985333280875737)

# %%
male_mean / global_mean
# Out:
# np.float64(1.0119970280230686)

# %%
df_group = df_train_full.groupby(by='gender').depression.agg(['mean'])
df_group['diff'] = df_group['mean'] - global_mean
df_group['risk'] = df_group['mean'] / global_mean
df_group
# Out:
#             mean      diff      risk
# gender
# female  0.179445 -0.002671  0.985333
# male    0.184301  0.002185  1.011997

# %%
from IPython.display import display

# %%
global_mean = df_train_full.depression.mean()
global_mean
# Out:
# np.float64(0.18211620469083156)

# %%
for col in cat_cols:
    df_group = df_train_full.groupby(by=col).depression.agg(['mean'])
    df_group['diff'] = df_group['mean'] - global_mean
    df_group['risk'] = df_group['mean'] / global_mean
    display(df_group)
# Out:
#               mean      diff      risk
# name
# aadhya    0.206070  0.023954  1.131532
# aahana    0.220557  0.038441  1.211077
# aakash    0.224490  0.042374  1.232673
# aanchal   0.196691  0.014575  1.080031
# aaradhya  0.195561  0.013445  1.073825
# ...            ...       ...       ...
# yashvi    0.149837 -0.032279  0.822756
# yogesh    0.309434  0.127318  1.699102
# yuvraj    0.166667 -0.015450  0.915167
# zara      0.082090 -0.100027  0.450754
# zoya      0.102041 -0.080075  0.560306
#
# [209 rows x 3 columns]
#             mean      diff      risk
# gender
# female  0.179445 -0.002671  0.985333
# male    0.184301  0.002185  1.011997
#                    mean      diff      risk
# city
# agra           0.195083  0.012967  1.071200
# ahmedabad      0.218030  0.035914  1.197202
# bangalore      0.172903 -0.009213  0.949409
# bhopal         0.238628  0.056512  1.310307
# chennai        0.191841  0.009724  1.053396
# delhi          0.188022  0.005906  1.032430
# faridabad      0.145143 -0.036973  0.796979
# ghaziabad      0.197859  0.015743  1.086444
# hyderabad      0.281145  0.099029  1.543766
# indore         0.156978 -0.025138  0.861967
# jaipur         0.183368  0.001251  1.006872
# kalyan         0.201206  0.019090  1.104821
# kanpur         0.123602 -0.058514  0.678697
# kolkata        0.170876 -0.011240  0.938282
# lucknow        0.216058  0.033942  1.186377
# ludhiana       0.193821  0.011705  1.064270
# meerut         0.136099 -0.046018  0.747318
# mumbai         0.129536 -0.052580  0.711284
# nagpur         0.143581 -0.038536  0.788401
# nashik         0.162948 -0.019168  0.894749
# noise          0.177215 -0.004901  0.973089
# patna          0.160839 -0.021277  0.883168
# pune           0.163104 -0.019013  0.895601
# rajkot         0.173840 -0.008276  0.954557
# srinagar       0.213071  0.030955  1.169972
# surat          0.199293  0.017177  1.094318
# thane          0.244315  0.062199  1.341533
# vadodara       0.165991 -0.016125  0.911455
# varanasi       0.143902 -0.038214  0.790168
# vasai-virar    0.200479  0.018363  1.100832
# visakhapatnam  0.163840 -0.018276  0.899648
#                                      mean      diff      risk
# working-professional-or-student
# student                          0.585200  0.403084  3.213335
# working professional             0.081938 -0.100179  0.449919
#                             mean      diff      risk
# profession
# accountant              0.068966 -0.113151  0.378690
# architect               0.098271 -0.083845  0.539605
# business analyst        0.056949 -0.125167  0.312709
# chef                    0.047826 -0.134290  0.262613
# chemist                 0.027197 -0.154920  0.149337
# civil engineer          0.075130 -0.106987  0.412536
# consultant              0.046810 -0.135306  0.257032
# content writer          0.018944 -0.163173  0.104020
# customer support        0.046341 -0.135775  0.254461
# data scientist          0.079807 -0.102309  0.438221
# digital marketer        0.044749 -0.137367  0.245716
# doctor                  0.052652 -0.129464  0.289112
# educational consultant  0.077980 -0.104137  0.428186
# electrician             0.039261 -0.142855  0.215582
# entrepreneur            0.021177 -0.160939  0.116285
# finanancial analyst     0.045923 -0.136193  0.252164
# financial analyst       0.081681 -0.100435  0.448511
# graphic designer        0.177297 -0.004819  0.973539
# hr manager              0.109012 -0.073104  0.598585
# investment banker       0.072785 -0.109331  0.399661
# judge                   0.105149 -0.076968  0.577371
# lawyer                  0.080427 -0.101689  0.441627
# manager                 0.086490 -0.095626  0.474918
# marketing manager       0.050601 -0.131515  0.277849
# mechanical engineer     0.106316 -0.075800  0.583780
# missing                 0.534694  0.352577  2.936002
# noise                   0.100000 -0.082116  0.549100
# pharmacist              0.025772 -0.156345  0.141512
# pilot                   0.053212 -0.128904  0.292188
# plumber                 0.063319 -0.118797  0.347683
# research analyst        0.063406 -0.118710  0.348161
# researcher              0.041467 -0.140649  0.227697
# sales executive         0.050292 -0.131825  0.276151
# software engineer       0.063333 -0.118783  0.347763
# teacher                 0.055834 -0.126282  0.306584
# travel consultant       0.046512 -0.135605  0.255395
# ux/ui designer          0.036721 -0.145395  0.201634
#                        mean      diff      risk
# sleep-duration
# 5-6 hours          0.165000 -0.017117  0.906013
# 7-8 hours          0.179899 -0.002217  0.987826
# less than 5 hours  0.234377  0.052261  1.286964
# more than 8 hours  0.139668 -0.042448  0.766919
# noise              0.142857 -0.039259  0.784429
#                     mean      diff      risk
# dietary-habits
# healthy         0.118268 -0.063848  0.649412
# moderate        0.166231 -0.015886  0.912772
# noise           0.450000  0.267884  2.470950
# unhealthy       0.261135  0.079018  1.433890
#               mean      diff      risk
# degree
# b.arch    0.157524 -0.024592  0.864966
# b.com     0.155658 -0.026458  0.854719
# b.ed      0.129940 -0.052176  0.713500
# b.pharm   0.117672 -0.064444  0.646137
# b.tech    0.213217  0.031100  1.170772
# ba        0.124664 -0.057452  0.684530
# bba       0.135411 -0.046705  0.743544
# bca       0.207092  0.024975  1.137140
# be        0.187500  0.005384  1.029562
# bhm       0.180958 -0.001158  0.993639
# bsc       0.156961 -0.025155  0.861871
# class 12  0.512385  0.330269  2.813508
# llb       0.150014 -0.032102  0.823729
# llm       0.115087 -0.067029  0.631941
# m.com     0.160816 -0.021300  0.883042
# m.ed      0.098841 -0.083275  0.542736
# m.pharm   0.094974 -0.087143  0.521500
# m.tech    0.141974 -0.040143  0.779577
# ma        0.177691 -0.004425  0.975703
# mba       0.122681 -0.059435  0.673644
# mbbs      0.168213 -0.013903  0.923657
# mca       0.146973 -0.035143  0.807031
# md        0.116519 -0.065597  0.639807
# me        0.072186 -0.109930  0.396374
# mhm       0.069838 -0.112279  0.383479
# msc       0.173769 -0.008347  0.954165
# noise     0.258427  0.076311  1.419022
# phd       0.146430 -0.035686  0.804047
#                                            mean      diff      risk
# have-you-ever-had-suicidal-thoughts-?
# no                                     0.049038 -0.133079  0.269266
# yes                                    0.318135  0.136019  1.746881
#                                       mean      diff      risk
# family-history-of-mental-illness
# no                                0.175338 -0.006778  0.962783
# yes                               0.188967  0.006851  1.037618

# %%
from sklearn.metrics import mutual_info_score

# %%
def calculate_mi(series):
    return mutual_info_score(series, df_train_full.depression)

df_mi = df_train_full[cat_cols].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')
    
    
display(df_mi.head())
display(df_mi.tail())
# Out:
#                                              MI
# profession                             0.135946
# working-professional-or-student        0.112467
# have-you-ever-had-suicidal-thoughts-?  0.066372
# degree                                 0.038233
# name                                   0.015593
#                                         MI
# dietary-habits                    0.011435
# sleep-duration                    0.004113
# city                              0.003955
# family-history-of-mental-illness  0.000156
# gender                            0.000020

# %% [markdown]
# ## Train

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble  import RandomForestClassifier
from sklearn.tree  import DecisionTreeClassifier
from sklearn.tree import export_text
from sklearn.feature_extraction import DictVectorizer

# %%
lr=LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
dv = DictVectorizer(sparse=False)

# %%
len(df_train.columns)
#df_train.head()
# Out:
# 19

# %%
train_dict=df_train[features].to_dict(orient='records')
print(train_dict[0])
X_train = dv.fit_transform(train_dict)

lr.fit(X_train, y_train)
# Out:
# {'age': 47.0, 'academic-pressure': 0.0, 'work-pressure': 4.0, 'cgpa': 0.0, 'study-satisfaction': 0.0, 'job-satisfaction': 1.0, 'work/study-hours': 12.0, 'financial-stress': 5.0, 'gender': 'male', 'city': 'kolkata', 'working-professional-or-student': 'working professional', 'profession': 'teacher', 'sleep-duration': '7-8 hours', 'dietary-habits': 'unhealthy', 'degree': 'llb', 'have-you-ever-had-suicidal-thoughts-?': 'yes', 'family-history-of-mental-illness': 'no'}
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
## Tree models
dt = DecisionTreeClassifier(max_depth=3, min_samples_leaf=15)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=15)

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- age <= 33.50
# |   |--- have-you-ever-had-suicidal-thoughts-?=yes <= 0.50
# |   |   |--- academic-pressure <= 3.50
# |   |   |   |--- class: 0
# |   |   |--- academic-pressure >  3.50
# |   |   |   |--- class: 1
# |   |--- have-you-ever-had-suicidal-thoughts-?=yes >  0.50
# |   |   |--- academic-pressure <= 2.50
# |   |   |   |--- class: 1
# |   |   |--- academic-pressure >  2.50
# |   |   |   |--- class: 1
# |--- age >  33.50
# |   |--- academic-pressure <= 2.50
# |   |   |--- have-you-ever-had-suicidal-thoughts-?=yes <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- have-you-ever-had-suicidal-thoughts-?=yes >  0.50
# |   |   |   |--- class: 0
# |   |--- academic-pressure >  2.50
# |   |   |--- have-you-ever-had-suicidal-thoughts-?=yes <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- have-you-ever-had-suicidal-thoughts-?=yes >  0.50
# |   |   |   |--- class: 1

# %%
val_dict=df_val[features].to_dict(orient='records')
X_val=dv.transform(val_dict)
y_pred=lr.predict(X_val)

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.9409737029140014

# %%
import time

# %%
def train(df, model):
    train_dict=df_train[features].to_dict(orient='records')
    X_train = dv.fit_transform(train_dict)
    model.fit(X_train, y_train)


    return model

# %%
t=time.time()
t
# Out:
# 1731271865.6795871

# %%
t0=time.time()
LR=train(df_train, lr)
t1=time.time()
print(t1-t0)
# Out:
# 6.618919610977173

# %% [markdown]
# ## Evaluate

# %%
def predict(X,model):
    y_pred=model.predict(X)
    return y_pred

# %%
val_dict=df_val[features].to_dict(orient='records')
X_val=dv.transform(val_dict)
y_pred=predict(X_val, LR)
accuracy_score(y_val, y_pred)
# Out:
# 0.9409737029140014

# %% [markdown]
# ## Model fine tuning

# %%
scores=[]
c_list=[0.045,0.05, 0.06, 0.07, 0.08,0.09,0.1,0.12, 0.2,0.3, 0.4, 0.5]
for l in ['l1','l2']:
    for c in tqdm(c_list):
        lr=LogisticRegression(penalty=l, solver='liblinear', C=c, max_iter=3000, random_state=42, class_weight=None)
        lr.fit(X_train, y_train)
        y_pred=lr.predict(X_val)
        accuracy=accuracy_score(y_val, y_pred)
        scores.append((l, c, accuracy))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:29<00:00,  2.45s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:13<00:00,  1.10s/it]

# %%
df_scores = pd.DataFrame(scores, columns=['L','C', 'accuracy'])
df_scores
# Out:
#      L      C  accuracy
# 0   l1  0.045  0.940370
# 1   l1  0.050  0.940227
# 2   l1  0.060  0.940689
# 3   l1  0.070  0.940689
# 4   l1  0.080  0.940547
# 5   l1  0.090  0.940832
# 6   l1  0.100  0.940725
# 7   l1  0.120  0.940689
# 8   l1  0.200  0.941080
# 9   l1  0.300  0.941436
# 10  l1  0.400  0.941329
# 11  l1  0.500  0.941294
# 12  l2  0.045  0.941365
# 13  l2  0.050  0.941542
# 14  l2  0.060  0.941400
# 15  l2  0.070  0.941436
# 16  l2  0.080  0.941507
# 17  l2  0.090  0.941294
# 18  l2  0.100  0.941294
# 19  l2  0.120  0.941222
# 20  l2  0.200  0.941151
# 21  l2  0.300  0.941116
# 22  l2  0.400  0.941116
# 23  l2  0.500  0.941151

# %%
colors = ['black', 'blue']
l_values = [1, 2]

for l, col in zip(l_values, colors):
    df_subset = df_scores[df_scores.L == l]
    print(df_subset)  # Check if the subset has data
    
    plt.plot(df_subset.C, df_subset.accuracy,
             color=col,
             label='Regularization=%d' % l)

plt.legend();
# Out:
# Empty DataFrame
# Columns: [L, C, accuracy]
# Index: []
# Empty DataFrame
# Columns: [L, C, accuracy]
# Index: []

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_scores.C, df_scores.accuracy); #

# %% [markdown]
# ### Fine tuning with tree models

# %%
from tqdm import tqdm
scores = []

for n in tqdm(range(1,20, 2)):
    dt = DecisionTreeClassifier(max_depth=n, random_state=1)
    dt.fit(X_train, y_train)
    y_pred=dt.predict(X_val)
    y_predp = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_predp)
    accuracy=accuracy_score(y_val, y_pred)
    
    scores.append((n, auc, accuracy))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:13<00:00,  1.33s/it]

# %%
df_scores = pd.DataFrame(scores, columns=['max_depth', 'auc', 'accuracy'])
plt.plot(df_scores.max_depth, df_scores.accuracy) # top auc at estimator 160 to 180

# %%
from tqdm import tqdm
scores = []

for n in tqdm(range(190,251, 10)):
    rf = RandomForestClassifier(n_estimators=n, random_state=1)
    rf.fit(X_train, y_train)
    y_pred=rf.predict(X_val)
    y_predp = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_predp)
    accuracy=accuracy=accuracy_score(y_val, y_pred)
    
    scores.append((n, auc, accuracy))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [07:01<00:00, 60.26s/it]

# %%
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc', 'accuracy'])

# %%
plt.plot(df_scores.n_estimators, df_scores.accuracy) # top auc at estimator 160 to 180

# %%
scores = []

for d in [5, 10, 15]:
    for n in range(150, 201, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=d,
                                    random_state=1)
        rf.fit(X_train, y_train)
        y_pred=lr.predict(X_val)
        y_predp = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_predp)
        accuracy=accuracy=accuracy_score(y_val, y_pred)
        scores.append((d, n, auc, accuracy))

# %%
df_scores = pd.DataFrame(scores, columns=['max_depth', 'n_estimators', 'auc', 'accuracy'])
plt.plot(df_scores.max_depth, df_scores.accuracy) # top auc at estimator 160 to 180

# %%
test_dict=df_test[features].to_dict(orient='records')
X_test=dv.transform(test_dict)
y_pred=predict(X_test, LR)
accuracy_score(y_test, y_pred)

# %% [markdown]
# ### Model Interpretation

# %%
lr.coef_[0].shape
# Out:
# (121,)

# %%
len(dv.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 len(dv.get_feature_names())
#
# AttributeError: 'DictVectorizer' object has no attribute 'get_feature_names'

# %%
dict(zip(dv.get_feature_names_out(), lr.coef_[0].round(3)))
# Out:
# {'academic-pressure': np.float64(0.852),
#  'age': np.float64(-0.167),
#  'cgpa': np.float64(0.07),
#  'city=agra': np.float64(-0.176),
#  'city=ahmedabad': np.float64(0.329),
#  'city=bangalore': np.float64(-0.01),
#  'city=bhopal': np.float64(0.029),
#  'city=chennai': np.float64(-0.179),
#  'city=delhi': np.float64(0.051),
#  'city=faridabad': np.float64(-0.015),
#  'city=ghaziabad': np.float64(0.157),
#  'city=hyderabad': np.float64(0.285),
#  'city=indore': np.float64(0.089),
#  'city=jaipur': np.float64(-0.133),
#  'city=kalyan': np.float64(0.083),
#  'city=kanpur': np.float64(-0.117),
#  'city=kolkata': np.float64(0.039),
#  'city=lucknow': np.float64(0.017),
#  'city=ludhiana': np.float64(-0.031),
#  'city=meerut': np.float64(-0.096),
#  'city=mumbai': np.float64(-0.371),
#  'city=nagpur': np.float64(-0.279),
#  'city=nashik': np.float64(0.09),
#  'city=noise': np.float64(-0.249),
#  'city=patna': np.float64(0.15),
#  'city=pune': np.float64(-0.056),
#  'city=rajkot': np.float64(0.026),
#  'city=srinagar': np.float64(-0.044),
#  'city=surat': np.float64(0.087),
#  'city=thane': np.float64(-0.018),
#  'city=vadodara': np.float64(0.054),
#  'city=varanasi': np.float64(0.008),
#  'city=vasai-virar': np.float64(0.0),
#  'city=visakhapatnam': np.float64(0.003),
#  'degree=b.arch': np.float64(-0.176),
#  'degree=b.com': np.float64(-0.174),
#  'degree=b.ed': np.float64(-0.002),
#  'degree=b.pharm': np.float64(0.036),
#  'degree=b.tech': np.float64(0.084),
#  'degree=ba': np.float64(-0.191),
#  'degree=bba': np.float64(0.012),
#  'degree=bca': np.float64(-0.021),
#  'degree=be': np.float64(0.167),
#  'degree=bhm': np.float64(0.03),
#  'degree=bsc': np.float64(0.064),
#  'degree=class 12': np.float64(-0.571),
#  'degree=llb': np.float64(0.175),
#  'degree=llm': np.float64(0.202),
#  'degree=m.com': np.float64(-0.114),
#  'degree=m.ed': np.float64(-0.007),
#  'degree=m.pharm': np.float64(-0.172),
#  'degree=m.tech': np.float64(-0.26),
#  'degree=ma': np.float64(0.083),
#  'degree=mba': np.float64(-0.274),
#  'degree=mbbs': np.float64(0.067),
#  'degree=mca': np.float64(0.019),
#  'degree=md': np.float64(0.259),
#  'degree=me': np.float64(0.052),
#  'degree=mhm': np.float64(-0.102),
#  'degree=msc': np.float64(-0.142),
#  'degree=noise': np.float64(0.32),
#  'degree=phd': np.float64(0.358),
#  'dietary-habits=healthy': np.float64(-0.6),
#  'dietary-habits=moderate': np.float64(-0.1),
#  'dietary-habits=noise': np.float64(-0.044),
#  'dietary-habits=unhealthy': np.float64(0.467),
#  'family-history-of-mental-illness=no': np.float64(-0.242),
#  'family-history-of-mental-illness=yes': np.float64(-0.035),
#  'financial-stress': np.float64(0.555),
#  'gender=female': np.float64(-0.132),
#  'gender=male': np.float64(-0.146),
#  'have-you-ever-had-suicidal-thoughts-?=no': np.float64(-1.361),
#  'have-you-ever-had-suicidal-thoughts-?=yes': np.float64(1.084),
#  'job-satisfaction': np.float64(-0.537),
#  'profession=accountant': np.float64(0.051),
#  'profession=architect': np.float64(0.468),
#  'profession=business analyst': np.float64(0.028),
#  'profession=chef': np.float64(-0.307),
#  'profession=chemist': np.float64(-1.003),
#  'profession=civil engineer': np.float64(0.566),
#  'profession=consultant': np.float64(-0.141),
#  'profession=content writer': np.float64(-0.873),
#  'profession=customer support': np.float64(0.096),
#  'profession=data scientist': np.float64(0.3),
#  'profession=digital marketer': np.float64(-0.717),
#  'profession=doctor': np.float64(0.049),
#  'profession=educational consultant': np.float64(0.151),
#  'profession=electrician': np.float64(-0.116),
#  'profession=entrepreneur': np.float64(-1.003),
#  'profession=finanancial analyst': np.float64(-0.177),
#  'profession=financial analyst': np.float64(0.173),
#  'profession=graphic designer': np.float64(0.816),
#  'profession=hr manager': np.float64(0.405),
#  'profession=investment banker': np.float64(0.786),
#  'profession=judge': np.float64(0.361),
#  'profession=lawyer': np.float64(0.174),
#  'profession=manager': np.float64(0.46),
#  'profession=marketing manager': np.float64(-0.151),
#  'profession=mechanical engineer': np.float64(0.623),
#  'profession=missing': np.float64(0.887),
#  'profession=noise': np.float64(-0.279),
#  'profession=pharmacist': np.float64(-0.871),
#  'profession=pilot': np.float64(0.28),
#  'profession=plumber': np.float64(0.144),
#  'profession=research analyst': np.float64(-0.287),
#  'profession=researcher': np.float64(0.131),
#  'profession=sales executive': np.float64(-0.14),
#  'profession=software engineer': np.float64(-0.319),
#  'profession=teacher': np.float64(-0.12),
#  'profession=travel consultant': np.float64(-0.268),
#  'profession=ux/ui designer': np.float64(-0.455),
#  'sleep-duration=5-6 hours': np.float64(-0.097),
#  'sleep-duration=7-8 hours': np.float64(-0.12),
#  'sleep-duration=less than 5 hours': np.float64(0.338),
#  'sleep-duration=more than 8 hours': np.float64(-0.428),
#  'sleep-duration=noise': np.float64(0.03),
#  'study-satisfaction': np.float64(-0.234),
#  'work-pressure': np.float64(0.635),
#  'work/study-hours': np.float64(0.133),
#  'working-professional-or-student=student': np.float64(-0.586),
#  'working-professional-or-student=working professional': np.float64(0.309)}

# %% [markdown]
# ## Submit

# %%
len(test)
# Out:
# 93800

# %%
features,df_test_submit= preprocess(test)
df_test_submit.shape, len(features)
# Out:
# ((93800, 19), 17)

# %%
df_test_submit.head(5)
# Out:
#        id     name  gender   age           city  \
# 0  140700   shivam    male  53.0  visakhapatnam
# 1  140701    sanya  female  58.0        kolkata
# 2  140702     yash    male  53.0         jaipur
# 3  140703   nalini  female  23.0         rajkot
# 4  140704  shaurya    male  47.0         kalyan
#
#   working-professional-or-student              profession  academic-pressure  \
# 0            working professional                   judge                0.0
# 1            working professional  educational consultant                0.0
# 2            working professional                 teacher                0.0
# 3                         student                 missing                5.0
# 4            working professional                 teacher                0.0
#
#    work-pressure  cgpa  study-satisfaction  job-satisfaction  \
# 0            2.0  0.00                 0.0               5.0
# 1            2.0  0.00                 0.0               4.0
# 2            4.0  0.00                 0.0               1.0
# 3            0.0  6.84                 1.0               0.0
# 4            5.0  0.00                 0.0               5.0
#
#       sleep-duration dietary-habits  degree  \
# 0  less than 5 hours       moderate     llb
# 1  less than 5 hours       moderate    b.ed
# 2          7-8 hours       moderate  b.arch
# 3  more than 8 hours       moderate     bsc
# 4          7-8 hours       moderate     bca
#
#   have-you-ever-had-suicidal-thoughts-?  work/study-hours  financial-stress  \
# 0                                    no               9.0               3.0
# 1                                    no               6.0               4.0
# 2                                   yes              12.0               4.0
# 3                                   yes              10.0               4.0
# 4                                   yes               3.0               4.0
#
#   family-history-of-mental-illness
# 0                              yes
# 1                               no
# 2                               no
# 3                               no
# 4                               no

# %%
lr=LogisticRegression(solver='liblinear', C=0.05, max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.05, max_iter=1000, random_state=42, solver='liblinear')

# %%
test_submit_dict=df_test_submit[features].to_dict(orient='records')
X_test_submit=dv.transform(test_submit_dict)
y_pred=predict(X_test_submit, LR)
y_pred[:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
submission=pd.read_csv('sample_submission.csv')

# %%
submission.head()
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           0
# 4  140704           0

# %%
submission['Depression']=y_pred

# %%
submission.head(10)
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0
# 5  140705           0
# 6  140706           0
# 7  140707           0
# 8  140708           0
# 9  140709           1

# %%
submission.Depression.value_counts(normalize=True)
# Out:
# Depression
# 0    0.824936
# 1    0.175064
# Name: proportion, dtype: float64

# %%
submission.to_csv('sub3.csv', index=False)
